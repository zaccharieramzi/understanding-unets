# %%
# %cd ../
# Out:
# /home/zaccharie/workspace/understanding-unets

# %%
from learning_wavelets.evaluate_tmp.baseline_eval import metrics_original, metrics_wavelets_from_ds, metrics_bm3d

# %%
metrics_original()
# Out:
# Stats for original noisy images: 0it [00:00, ?it/s]/home/zaccharie/workspace/understanding-unets/learning_wavelets/evaluate_tmp/runstats.py:10: UserWarning: DEPRECATED: skimage.measure.compare_psnr has been moved to skimage.metrics.peak_signal_noise_ratio. It will be removed from skimage.measure in version 0.18.
#   return compare_psnr(gt, pred, data_range=1)
# /home/zaccharie/workspace/understanding-unets/learning_wavelets/evaluate_tmp/runstats.py:19: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
#   gt, pred, multichannel=True, data_range=1
# Stats for original noisy images: 68it [00:01, 57.83it/s]
# Stats for original noisy images: 68it [00:01, 57.31it/s]
# Stats for original noisy images: 68it [00:01, 56.71it/s]
# Stats for original noisy images: 68it [00:01, 59.41it/s]
# Stats for original noisy images: 68it [00:01, 63.05it/s]
# ...

# %%
metrics_wavelets_from_ds()
# Out:
# Stats for original noisy images: 68it [00:14,  4.66it/s]
# Stats for original noisy images: 68it [00:16,  4.23it/s]
# Stats for original noisy images: 68it [00:20,  3.38it/s]
# Stats for original noisy images: 68it [00:19,  3.57it/s]
# Stats for original noisy images: 68it [00:18,  3.65it/s]
# Stats for original noisy images: 68it [00:18,  3.59it/s]
# Stats for original noisy images: 68it [00:20,  3.33it/s]
# Stats for original noisy images: 68it [00:18,  3.73it/s]
# Stats for original noisy images: 68it [00:18,  3.75it/s]
# Stats for original noisy images: 68it [00:16,  4.12it/s]
#   soft_thresh wavelet_id  noise_std        PSNR      SSIM
# 0       False         24     0.0001  127.289495  1.000000
# 1       False         24     5.0000   35.765024  0.945664
# 2       False         24    15.0000   29.556904  0.823377
# 3       False         24    20.0000   28.250759  0.776625
# 4       False         24    25.0000   27.320294  0.736837
# ...

# %%
metrics_bm3d()
# Out:
# Stats for original noisy images: 68it [06:15,  5.52s/it]
# Stats for original noisy images: 68it [44:42, 39.45s/it]
# Stats for original noisy images: 68it [06:14,  5.50s/it]
# Stats for original noisy images: 68it [06:17,  5.55s/it]
# Stats for original noisy images: 68it [07:12,  6.36s/it]
# Stats for original noisy images: 68it [06:55,  6.11s/it]
# Stats for original noisy images: 68it [07:03,  6.22s/it]
# Stats for original noisy images: 68it [07:18,  6.45s/it]
# Stats for original noisy images: 68it [07:10,  6.33s/it]
# Stats for original noisy images: 68it [07:13,  6.37s/it]
#    noise_std        PSNR      SSIM
# 0     0.0001  126.990663  1.000000
# 1     5.0000   37.555295  0.964594
# 2    15.0000   31.156184  0.867853
# 3    20.0000   29.696154  0.824613
# 4    25.0000   28.635456  0.786881
# 5    30.0000   27.811555  0.753479
# 6    50.0000   25.715751  0.652242
# 7    55.0000   25.347846  0.631612
# 8    60.0000   25.020453  0.613532
# 9    75.0000   24.206666  0.565937
